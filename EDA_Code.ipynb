# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('bmh')

# %%
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/My Drive/Loan.csv')
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0      2018-01-01   45         39948          617         Employed
# 1      2018-01-02   38         39709          628         Employed
# 2      2018-01-03   47         40724          570         Employed
# 3      2018-01-04   58         69084          545         Employed
# 4      2018-01-05   37        103264          594         Employed
#
#   EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  ...  \
# 0         Master          22       13152            48       Married  ...
# 1      Associate          15       26045            48        Single  ...
# 2       Bachelor          26       17627            36       Married  ...
# 3    High School          34       37898            96        Single  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ApplicationDate             20000 non-null  object
#  1   Age                         20000 non-null  int64
#  2   AnnualIncome                20000 non-null  int64
#  3   CreditScore                 20000 non-null  int64
#  4   EmploymentStatus            20000 non-null  object
#  5   EducationLevel              20000 non-null  object
#  6   Experience                  20000 non-null  int64
#  7   LoanAmount                  20000 non-null  int64
#  8   LoanDuration                20000 non-null  int64
#  9   MaritalStatus               20000 non-null  object
#  10  NumberOfDependents          20000 non-null  int64
#  11  HomeOwnershipStatus         20000 non-null  object
#  12  MonthlyDebtPayments         20000 non-null  int64
# ...

# %%
df.describe()
# Out:
#                 Age   AnnualIncome   CreditScore    Experience     LoanAmount  \
# count  20000.000000   20000.000000  20000.000000  20000.000000   20000.000000
# mean      39.752600   59161.473550    571.612400     17.522750   24882.867800
# std       11.622713   40350.845168     50.997358     11.316836   13427.421217
# min       18.000000   15000.000000    343.000000      0.000000    3674.000000
# 25%       32.000000   31679.000000    540.000000      9.000000   15575.000000
# 50%       40.000000   48566.000000    578.000000     17.000000   21914.500000
# 75%       48.000000   74391.000000    609.000000     25.000000   30835.000000
# max       80.000000  485341.000000    712.000000     61.000000  184732.000000
#
#        LoanDuration  NumberOfDependents  MonthlyDebtPayments  \
# count  20000.000000        20000.000000         20000.000000
# mean      54.057000            1.517300           454.292700
# std       24.664857            1.386325           240.507609
# ...

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
sns.histplot(df['Age'], kde=True, bins=30, ax=axes[0], color='skyblue')
axes[0].set_title('Age Distribution')
sns.histplot(df['AnnualIncome'], kde=True, bins=30, ax=axes[1], color='green')
axes[1].set_title('Annual Income Distribution')
sns.histplot(df['LoanAmount'], kde=True, bins=30, ax=axes[2], color='orange')
axes[2].set_title('Loan Amount Distribution')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
numeric_data = df.select_dtypes(include=['number'])
correlation_matrix = numeric_data.corr()
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=False, fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
for feature in categorical_features:
    approval_rates = df.groupby(feature)['LoanApproved'].mean() * 100
    plt.figure(figsize=(8, 8))
    plt.pie(
        approval_rates,
        labels=approval_rates.index,
        autopct='%1.1f%%',
        startangle=140,
        colors=sns.color_palette('viridis', len(approval_rates))
    )
    plt.title(f'Loan Approval Rate by {feature}')
    plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

encoded_data = df.copy()
label_encoders = {}
categorical_features = ['EmploymentStatus', 'EducationLevel', 'MaritalStatus', 'HomeOwnershipStatus', 'LoanPurpose']

for col in categorical_features:
    label_encoders[col] = LabelEncoder()
    encoded_data[col] = label_encoders[col].fit_transform(df[col])

X = encoded_data.drop(columns=['LoanApproved', 'ApplicationDate', 'RiskScore'])
y = df['LoanApproved']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

importances = pd.Series(clf.feature_importances_, index=X.columns).sort_values(ascending=False)

plt.figure(figsize=(10, 6))
importances.plot(kind='bar', color='purple')
plt.title('Feature Importance')
plt.ylabel('Importance Score')
plt.show()

# %%
approval_counts = df['LoanApproved'].value_counts(normalize=True) * 100

plt.figure(figsize=(8, 8))
plt.pie(
    approval_counts,
    labels=['Rejected', 'Approved'],
    autopct='%1.1f%%',
    startangle=140,
    colors=['red', 'green'],
    explode=[0.1, 0]
)
plt.title('Loan Approval Rates')
plt.show()
